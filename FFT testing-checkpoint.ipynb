# %%
from scipy.fftpack import fft
import numpy as np
import matplotlib.pyplot as plt  

# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#print x
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

from scipy.signal import blackman
w = blackman(N)
ywf = fft(y*w)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', 'FFT w. window'])
plt.grid()
plt.show()

# %%
# Number of sample points
N = 60
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#print x
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

ywf = fft(y*100)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', '2nd FFT'])
plt.grid()
plt.show()

print x.size
print xf.size
print xf[1:N//2].size
# Out:
# 60
# 30
# 29

# %%
from scipy.fftpack import fft
import numpy as np
import matplotlib.pyplot as plt 
import random


# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#print x
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)

plt.plot(x,y)
plt.show()
yf = fft(y)

# ywf = fft(y*100)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

plt.semilogy(xf[0:N//2], 2.0/N * np.abs(yf[0:N//2]), '-b')
# plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
# plt.legend(['FFT', '2nd FFT'])
plt.grid()
plt.show()

# %%
from scipy.fftpack import fft
import numpy as np
import matplotlib.pyplo  t as plt 
import scipy import sigmal

# Number of sample points
N = 60
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#print x
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

ywf = fft(y*100)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', '2nd FFT'])
plt.grid()
plt.show()

print x.size
print xf.size
print xf[1:N//2].size

# %%
from scipy.fftpack import fft
import numpy as np
import matplotlib.pyplot as plt 
from scipy import signal

# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#print x
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

ywf = fft(y*100)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)


f, Pxx_den = signal.periodogram(y, 800)
plt.semilogy(f[1:], Pxx_den[1:])


plt.legend(['PSD FFT'])
plt.grid()
plt.show()

print x.size
print xf.size
print xf[1:N//2].size
# Out:
# 600
# 300
# 299
